# %% [markdown]
# <a href="https://colab.research.google.com/github/YOUGALAKSHMI/Data-Analysis-Visuvalization/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #create a list

# %%
dep=["CSE","IT","ISE","CT","ECE","EIE","EEE","CSE","EIE"]

# %%
print(dep)
# Out:
# ['CSE', 'IT', 'ISE', 'CT', 'ECE', 'EIE', 'EEE', 'CSE', 'EIE']

# %% [markdown]
# #access using negative index

# %%
print(dep[0])
# Out:
# CSE

# %%
print(dep[-1])
# Out:
# EIE

# %%
print(dep[::-1])
# Out:
# ['EIE', 'CSE', 'EEE', 'EIE', 'ECE', 'CT', 'ISE', 'IT', 'CSE']

# %%
print(dep[1::3])
# Out:
# ['IT', 'ECE', 'CSE']

# %%
print(dep[-1::-3])
# Out:
# ['EIE', 'EIE', 'ISE']

# %%
print(dep[1:5])
# Out:
# ['IT', 'ISE', 'CT', 'ECE']

# %% [markdown]
# #append list

# %%
dep.append("Mech")
print(dep)
# Out:
# ['CSE', 'IT', 'ISE', 'CT', 'ECE', 'EIE', 'EEE', 'CSE', 'EIE', 'Mech']

# %%
#update / change
dep[5]=("mech")
print(dep)
# Out:
# ['CSE', 'IT', 'ISE', 'CT', 'ECE', 'mech', 'EEE', 'CSE', 'EIE', 'Mech']

# %%
#reterive
for x in dep:
  print(x)
# Out:
# CSE
# IT
# ISE
# CT
# ECE
# mech
# EEE
# CSE
# EIE
# Mech

# %%
dep1=["fd","ct","bt"]

# %%
#join of two list
DEP=dep+dep1
print(DEP)
# Out:
# ['CSE', 'IT', 'ISE', 'CT', 'ECE', 'mech', 'EEE', 'CSE', 'EIE', 'Mech', 'fd', 'ct', 'bt']

# %%
#delete/remove ITEMS IN LIST
DEP.remove("CSE")
print(DEP)
# Out:
# ['IT', 'ISE', 'CT', 'ECE', 'mech', 'EEE', 'CSE', 'EIE', 'Mech', 'fd', 'ct', 'bt']

# %% [markdown]
# #create tuple

# %%
branch=("CSE","IT","ISE","CT","ECE","EIE","EEE","CSE","EIE")

# %%
print(branch)
# Out:
# ('CSE', 'IT', 'ISE', 'CT', 'ECE', 'EIE', 'EEE', 'CSE', 'EIE')

# %% [markdown]
# #change values in tupule

# %%
x=list(branch)

# %%
print(x)
# Out:
# ['CSE', 'IT', 'ISE', 'CT', 'ECE', 'EIE', 'EEE', 'CSE', 'EIE']

# %%
x[4]="mech"
y=tuple(x)
print(y)
# Out:
# ('CSE', 'IT', 'ISE', 'CT', 'mech', 'EIE', 'EEE', 'CSE', 'EIE')

# %% [markdown]
# #append,delete,join

# %%
s=list(y)
s.append("ece")
y=tuple(s)
print(y)
# Out:
# ('CSE', 'IT', 'ISE', 'CT', 'mech', 'EIE', 'EEE', 'CSE', 'EIE', 'ece', 'ece')

# %%
z=list(y)
print(z)
# Out:
# ['CSE', 'IT', 'ISE', 'CT', 'mech', 'EIE', 'EEE', 'CSE', 'EIE', 'ece', 'ece']

# %%
#delte / remove
z.remove("CSE")
y=tuple(z)
print(y)
# Out:
# ('IT', 'ISE', 'CT', 'mech', 'EIE', 'EEE', 'EIE', 'ece', 'ece')

# %%
#join
i=("ad","fd","bt")
j=list(i)
k=list(y)
l=k+j
l=tuple(l)
print(l)
# Out:
# ('IT', 'ISE', 'CT', 'mech', 'EIE', 'EEE', 'EIE', 'ece', 'ece', 'ad', 'fd', 'bt')

# %% [markdown]
# #create a set

# %%
dep={"cse","it","ece","eie"}

# %%
print(dep)
# Out:
# {'ece', 'eie', 'cse', 'it'}

# %% [markdown]
# #append,delete,join

# %%
dep.add("mech")
print(dep)
# Out:
# {'eie', 'cse', 'ece', 'it', 'mech'}

# %%
#delete/remove
dep.remove("cse")
print(dep)
# Out:
# {'eie', 'ece', 'it', 'mech'}

# %%
#join
dep1={"ad","fd","bt"}
dep.update(dep1)
print(dep)
# Out:
# {'eie', 'ece', 'fd', 'it', 'bt', 'ad', 'mech'}

# %%
#change
dep1={"au"}
dep={"cse","it","ece","eie"}
dep.update(dep1)
print(dep)
# Out:
# {'ece', 'eie', 'au', 'it', 'cse'}

# %% [markdown]
# #dictionary

# %%
dict={1:"cse",2:"it",3:"ece"}

# %%
print(dict)
# Out:
# {1: 'cse', 2: 'it', 3: 'ece'}

# %%
dict[2]=("mech")
print(dict)
# Out:
# {1: 'cse', 2: 'mech', 3: 'ece'}

# %%
#append
dict["Cluster 4"]="it"
print(dict)
# Out:
# {1: 'cse', 2: 'mech', 3: 'ece', 'Cluster 3': 'it', 'Cluster 4': 'it'}

# %%
#remove/delete
del dict[1]
print(dict)
# Out:
# {2: 'mech', 3: 'ece', 'Cluster 3': 'it'}

# %%
#clear all
dict1={1:"cse",2:"it",3:"ece"}
dict1.clear()
print(dict1)
# Out:
# {}

# %%
#update /change
dict["Cluster 5"]="it"
print(dict)
# Out:
# {2: 'mech', 3: 'ece', 'Cluster 3': 'it', 'Cluster 5': 'it'}

# %%
#join
dict1={4:"cse",6:"it",7:"ece"}
dict.update(dict1)
print(dict)
# Out:
# {2: 'mech', 3: 'ece', 'Cluster 3': 'it', 'Cluster 5': 'it', 4: 'cse', 6: 'it', 7: 'ece'}

# %%
#create a nested dict
clg={"BIT":{1:"ece",2:"mech"},"KCT":{1:"cse",2:"it"}}
print(clg)
# Out:
# {'BIT': {1: 'ece', 2: 'mech'}, 'KCT': {1: 'cse', 2: 'it'}}

# %%
#change values in nested dict
clg["BIT"][1]="ECE"
print(clg)
# Out:
# {'BIT': {1: 'ECE', 2: 'mech'}, 'KCT': {1: 'cse', 2: 'it'}}

# %% [markdown]
# #task

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/drive/MyDrive/breast-cancer.data',header=None)

# %%
data
# Out:
#                         0      1        2      3    4   5  6      7  \
# 0    no-recurrence-events  30-39  premeno  30-34  0-2  no  3   left
# 1    no-recurrence-events  40-49  premeno  20-24  0-2  no  2  right
# 2    no-recurrence-events  40-49  premeno  20-24  0-2  no  2   left
# 3    no-recurrence-events  60-69     ge40  15-19  0-2  no  2  right
# 4    no-recurrence-events  40-49  premeno    0-4  0-2  no  2  right
# ..                    ...    ...      ...    ...  ...  .. ..    ...
# 281     recurrence-events  30-39  premeno  30-34  0-2  no  2   left
# 282     recurrence-events  30-39  premeno  20-24  0-2  no  3   left
# 283     recurrence-events  60-69     ge40  20-24  0-2  no  1  right
# 284     recurrence-events  40-49     ge40  30-34  3-5  no  3   left
# 285     recurrence-events  50-59     ge40  30-34  3-5  no  3   left
#
#              8    9
# 0     left_low   no
# 1     right_up   no
# 2     left_low   no
# 3      left_up   no
# 4    right_low   no
# ..         ...  ...
# ...

# %%
data=pd.read_csv('/content/drive/MyDrive/breast-cancer.data',names=["Class","age","menopause","tumor-size","inv-nodes","nodecaps","deg-malig","breast","breast-quad","irradiat"])

# %%
data
# Out:
#                     Class    age menopause tumor-size inv-nodes nodecaps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2       no
# 1    no-recurrence-events  40-49   premeno      20-24       0-2       no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2       no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2       no
# 4    no-recurrence-events  40-49   premeno        0-4       0-2       no
# ..                    ...    ...       ...        ...       ...      ...
# 281     recurrence-events  30-39   premeno      30-34       0-2       no
# 282     recurrence-events  30-39   premeno      20-24       0-2       no
# 283     recurrence-events  60-69      ge40      20-24       0-2       no
# 284     recurrence-events  40-49      ge40      30-34       3-5       no
# 285     recurrence-events  50-59      ge40      30-34       3-5       no
#
#      deg-malig breast breast-quad irradiat
# 0            3   left    left_low       no
# ...

# %%
data.head()
# Out:
#                   Class    age menopause tumor-size inv-nodes nodecaps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2       no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2       no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2       no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2       no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2       no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %%
data.tail()
# Out:
#                  Class    age menopause tumor-size inv-nodes nodecaps  \
# 281  recurrence-events  30-39   premeno      30-34       0-2       no
# 282  recurrence-events  30-39   premeno      20-24       0-2       no
# 283  recurrence-events  60-69      ge40      20-24       0-2       no
# 284  recurrence-events  40-49      ge40      30-34       3-5       no
# 285  recurrence-events  50-59      ge40      30-34       3-5       no
#
#      deg-malig breast breast-quad irradiat
# 281          2   left     left_up       no
# 282          3   left     left_up      yes
# 283          1  right     left_up       no
# 284          3   left    left_low       no
# 285          3   left    left_low       no

# %% [markdown]
# #create list

# %%
l=list(data.menopause	)

# %% [markdown]
# #accessing items

# %%
print(l)
# Out:
# ['premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'pre
# ...

# %%
print(l[::-1])
# Out:
# ['ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'lt40', 'lt40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'p
# ...

# %%
print(l[1:6:])
# Out:
# ['premeno', 'premeno', 'ge40', 'premeno', 'ge40']

# %%
print(l[:-6:-1])
# Out:
# ['ge40', 'ge40', 'ge40', 'premeno', 'premeno']

# %%
print(l[1::3])
# Out:
# ['premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'lt40', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40']

# %% [markdown]
# #operations

# %%
#append
l.append("premeno")
print(l)
# Out:
# ['premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'pre
# ...

# %%
#update/insert
l[5]="lt40"
print(l)
# Out:
# ['premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'lt40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'pre
# ...

# %%
#reterive
for x in l:
  print(x)
# Out:
# premeno
# premeno
# premeno
# ge40
# premeno
# lt40
# premeno
# ge40
# premeno
# premeno
# premeno
# ge40
# lt40
# ge40
# premeno
# lt40
# premeno
# premeno
# ge40
# ge40
# ge40
# ge40
# premeno
# premeno
# premeno
# premeno
# premeno
# ge40
# premeno
# ge40
# ge40
# premeno
# premeno
# ge40
# ge40
# premeno
# ge40
# ge40
# premeno
# premeno
# ge40
# ge40
# ge40
# premeno
# ge40
# ge40
# premeno
# premeno
# premeno
# premeno
# lt40
# premeno
# premeno
# ge40
# ge40
# ge40
# ge40
# ge40
# ge40
# ge40
# premeno
# premeno
# ge40
# premeno
# premeno
# premeno
# premeno
# ge40
# ge40
# ge40
# ge40
# premeno
# ge40
# premeno
# premeno
# ge40
# ge40
# premeno
# premeno
# premeno
# ge40
# ge40
# ge40
# ge40
# premeno
# ge40
# ge40
# ge40
# ge40
# premeno
# premeno
# ge40
# ge40
# ge40
# premeno
# premeno
# ge40
# ge40
# premeno
# premeno
# ge40
# ge40
# premeno
# premeno
# premeno
# premeno
# premeno
# premeno
# premeno
# ge40
# ge40
# ge40
# premeno
# premeno
# premeno
# ge40
# premeno
# ...

# %%
#join list
k=list(data.irradiat)
m=l+k
print(m)
# Out:
# ['premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'lt40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'pre
# ...

# %%
#delete/remove ITEMS IN LIST
l.remove("lt40")
print(l)
# Out:
# ['premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', '
# ...

# %% [markdown]
# #create tuple

# %%
t=tuple(data.age)

# %%
print(t)
# Out:
# ('30-39', '40-49', '40-49', '60-69', '40-49', '60-69', '50-59', '60-69', '40-49', '40-49', '40-49', '50-59', '60-69', '50-59', '40-49', '60-69', '40-49', '50-59', '60-69', '50-59', '50-59', '60-69', '30-39', '50-59', '50-59', '40-49', '50-59', '60-69', '40-49', '60-69', '50-59', '50-59', '50-59', '50-59', '50-59', '30-39', '50-59', '50-59', '40-49', '40-49', '50-59', '60-69', '60-69', '40-49', '50-59', '50-59', '40-49', '50-59', '40-49', '40-49', '50-59', '30-39', '50-59', '70-79', '70-79', '70-79', '50-59', '50-59', '60-69', '60-69', '40-49', '40-49', '50-59', '20-29', '40-49', '40-49', '40-49', '50-59', '50-59', '60-69', '60-69', '40-49', '60-69', '50-59', '30-39', '50-59', '50-59', '30-39', '50-59', '40-49', '50-59', '60-69', '60-69', '50-59', '40-49', '50-59', '60-69', '70-79', '50-59', '40-49', '30-39', '50-59', '50-59', '60-69', '50-59', '40-49', '60-69', '60-69', '40-49', '30-39', '40-49', '50-59', '50-59', '40-49', '40-49', '40-49', '40-49', '30-39', '40-49', '60-69', '50-59'
# ...

# %% [markdown]
# #operations on tuple

# %%
q=list(t)
print(q)
# Out:
# ['30-39', '40-49', '40-49', '60-69', '40-49', '60-69', '50-59', '60-69', '40-49', '40-49', '40-49', '50-59', '60-69', '50-59', '40-49', '60-69', '40-49', '50-59', '60-69', '50-59', '50-59', '60-69', '30-39', '50-59', '50-59', '40-49', '50-59', '60-69', '40-49', '60-69', '50-59', '50-59', '50-59', '50-59', '50-59', '30-39', '50-59', '50-59', '40-49', '40-49', '50-59', '60-69', '60-69', '40-49', '50-59', '50-59', '40-49', '50-59', '40-49', '40-49', '50-59', '30-39', '50-59', '70-79', '70-79', '70-79', '50-59', '50-59', '60-69', '60-69', '40-49', '40-49', '50-59', '20-29', '40-49', '40-49', '40-49', '50-59', '50-59', '60-69', '60-69', '40-49', '60-69', '50-59', '30-39', '50-59', '50-59', '30-39', '50-59', '40-49', '50-59', '60-69', '60-69', '50-59', '40-49', '50-59', '60-69', '70-79', '50-59', '40-49', '30-39', '50-59', '50-59', '60-69', '50-59', '40-49', '60-69', '60-69', '40-49', '30-39', '40-49', '50-59', '50-59', '40-49', '40-49', '40-49', '40-49', '30-39', '40-49', '60-69', '50-59'
# ...

# %%
#update
q[4]="90"
r=tuple(q)
print(r)
# Out:
# ('30-39', '40-49', '40-49', '60-69', '90', '60-69', '50-59', '60-69', '40-49', '40-49', '40-49', '50-59', '60-69', '50-59', '40-49', '60-69', '40-49', '50-59', '60-69', '50-59', '50-59', '60-69', '30-39', '50-59', '50-59', '40-49', '50-59', '60-69', '40-49', '60-69', '50-59', '50-59', '50-59', '50-59', '50-59', '30-39', '50-59', '50-59', '40-49', '40-49', '50-59', '60-69', '60-69', '40-49', '50-59', '50-59', '40-49', '50-59', '40-49', '40-49', '50-59', '30-39', '50-59', '70-79', '70-79', '70-79', '50-59', '50-59', '60-69', '60-69', '40-49', '40-49', '50-59', '20-29', '40-49', '40-49', '40-49', '50-59', '50-59', '60-69', '60-69', '40-49', '60-69', '50-59', '30-39', '50-59', '50-59', '30-39', '50-59', '40-49', '50-59', '60-69', '60-69', '50-59', '40-49', '50-59', '60-69', '70-79', '50-59', '40-49', '30-39', '50-59', '50-59', '60-69', '50-59', '40-49', '60-69', '60-69', '40-49', '30-39', '40-49', '50-59', '50-59', '40-49', '40-49', '40-49', '40-49', '30-39', '40-49', '60-69', '50-59', '
# ...

# %%
#append
v=list(r)
v.append("100")
print(tuple(v))
# Out:
# ('30-39', '40-49', '40-49', '60-69', '90', '60-69', '50-59', '60-69', '40-49', '40-49', '40-49', '50-59', '60-69', '50-59', '40-49', '60-69', '40-49', '50-59', '60-69', '50-59', '50-59', '60-69', '30-39', '50-59', '50-59', '40-49', '50-59', '60-69', '40-49', '60-69', '50-59', '50-59', '50-59', '50-59', '50-59', '30-39', '50-59', '50-59', '40-49', '40-49', '50-59', '60-69', '60-69', '40-49', '50-59', '50-59', '40-49', '50-59', '40-49', '40-49', '50-59', '30-39', '50-59', '70-79', '70-79', '70-79', '50-59', '50-59', '60-69', '60-69', '40-49', '40-49', '50-59', '20-29', '40-49', '40-49', '40-49', '50-59', '50-59', '60-69', '60-69', '40-49', '60-69', '50-59', '30-39', '50-59', '50-59', '30-39', '50-59', '40-49', '50-59', '60-69', '60-69', '50-59', '40-49', '50-59', '60-69', '70-79', '50-59', '40-49', '30-39', '50-59', '50-59', '60-69', '50-59', '40-49', '60-69', '60-69', '40-49', '30-39', '40-49', '50-59', '50-59', '40-49', '40-49', '40-49', '40-49', '30-39', '40-49', '60-69', '50-59', '
# ...

# %%
#delete/remove
v=list(v)
v.remove("90")
print(tuple(v))
# Out:
# ('30-39', '40-49', '40-49', '60-69', '60-69', '50-59', '60-69', '40-49', '40-49', '40-49', '50-59', '60-69', '50-59', '40-49', '60-69', '40-49', '50-59', '60-69', '50-59', '50-59', '60-69', '30-39', '50-59', '50-59', '40-49', '50-59', '60-69', '40-49', '60-69', '50-59', '50-59', '50-59', '50-59', '50-59', '30-39', '50-59', '50-59', '40-49', '40-49', '50-59', '60-69', '60-69', '40-49', '50-59', '50-59', '40-49', '50-59', '40-49', '40-49', '50-59', '30-39', '50-59', '70-79', '70-79', '70-79', '50-59', '50-59', '60-69', '60-69', '40-49', '40-49', '50-59', '20-29', '40-49', '40-49', '40-49', '50-59', '50-59', '60-69', '60-69', '40-49', '60-69', '50-59', '30-39', '50-59', '50-59', '30-39', '50-59', '40-49', '50-59', '60-69', '60-69', '50-59', '40-49', '50-59', '60-69', '70-79', '50-59', '40-49', '30-39', '50-59', '50-59', '60-69', '50-59', '40-49', '60-69', '60-69', '40-49', '30-39', '40-49', '50-59', '50-59', '40-49', '40-49', '40-49', '40-49', '30-39', '40-49', '60-69', '50-59', '50-59'
# ...

# %%
#join
v=list(v)
w=l+v
print(tuple(w))
# Out:
# ('premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', '
# ...

# %% [markdown]
# #create set

# %%
s=set(data.Class)

# %%
print(s)
# Out:
# {'recurrence-events', 'no-recurrence-events'}

# %%
i=set(data.nodecaps)

# %%
print(i)
# Out:
# {'yes', 'no', '?'}

# %% [markdown]
# #operations on set

# %%
i.add("maybe")
print(i)
# Out:
# {'yes', 'maybe', 'no', '?'}

# %%
#delete/remove
i.remove("?")
print(i)
# Out:
# {'yes', 'maybe', 'no'}

# %%
#join
s.update(i)
print(s)
# Out:
# {'yes', 'maybe', 'no', 'no-recurrence-events', 'recurrence-events'}

# %%
#change
i={"or"}
s.update(i)
print(s)
# Out:
# {'yes', 'maybe', 'no', 'no-recurrence-events', 'or', 'recurrence-events'}

# %% [markdown]
# #create dict

# %%
df1_dict=data.to_dict()

# %%
#dict
df1_dict
# Out:
# {'Class': {0: 'no-recurrence-events',
#   1: 'no-recurrence-events',
#   2: 'no-recurrence-events',
#   3: 'no-recurrence-events',
#   4: 'no-recurrence-events',
#   5: 'no-recurrence-events',
#   6: 'no-recurrence-events',
#   7: 'no-recurrence-events',
#   8: 'no-recurrence-events',
#   9: 'no-recurrence-events',
#   10: 'no-recurrence-events',
#   11: 'no-recurrence-events',
#   12: 'no-recurrence-events',
#   13: 'no-recurrence-events',
#   14: 'no-recurrence-events',
#   15: 'no-recurrence-events',
#   16: 'no-recurrence-events',
#   17: 'no-recurrence-events',
#   18: 'no-recurrence-events',
#   19: 'no-recurrence-events',
#   20: 'no-recurrence-events',
#   21: 'no-recurrence-events',
#   22: 'no-recurrence-events',
#   23: 'no-recurrence-events',
#   24: 'no-recurrence-events',
#   25: 'no-recurrence-events',
#   26: 'no-recurrence-events',
#   27: 'no-recurrence-events',
#   28: 'no-recurrence-events',
#   29: 'no-recurrence-events',
#   30: 'no-recurrence-events',
# ...

# %%
df1_dict[285]=("yes")
print(df1_dict)
# Out:
# {'Class': {0: 'no-recurrence-events', 1: 'no-recurrence-events', 2: 'no-recurrence-events', 3: 'no-recurrence-events', 4: 'no-recurrence-events', 5: 'no-recurrence-events', 6: 'no-recurrence-events', 7: 'no-recurrence-events', 8: 'no-recurrence-events', 9: 'no-recurrence-events', 10: 'no-recurrence-events', 11: 'no-recurrence-events', 12: 'no-recurrence-events', 13: 'no-recurrence-events', 14: 'no-recurrence-events', 15: 'no-recurrence-events', 16: 'no-recurrence-events', 17: 'no-recurrence-events', 18: 'no-recurrence-events', 19: 'no-recurrence-events', 20: 'no-recurrence-events', 21: 'no-recurrence-events', 22: 'no-recurrence-events', 23: 'no-recurrence-events', 24: 'no-recurrence-events', 25: 'no-recurrence-events', 26: 'no-recurrence-events', 27: 'no-recurrence-events', 28: 'no-recurrence-events', 29: 'no-recurrence-events', 30: 'no-recurrence-events', 31: 'no-recurrence-events', 32: 'no-recurrence-events', 33: 'no-recurrence-events', 34: 'no-recurrence-events', 35: 'no-recurrenc
# ...

# %%
#append
df1_dict["286"]="maybe"
print(df1_dict)
# Out:
# {'Class': {0: 'no-recurrence-events', 1: 'no-recurrence-events', 2: 'no-recurrence-events', 3: 'no-recurrence-events', 4: 'no-recurrence-events', 5: 'no-recurrence-events', 6: 'no-recurrence-events', 7: 'no-recurrence-events', 8: 'no-recurrence-events', 9: 'no-recurrence-events', 10: 'no-recurrence-events', 11: 'no-recurrence-events', 12: 'no-recurrence-events', 13: 'no-recurrence-events', 14: 'no-recurrence-events', 15: 'no-recurrence-events', 16: 'no-recurrence-events', 17: 'no-recurrence-events', 18: 'no-recurrence-events', 19: 'no-recurrence-events', 20: 'no-recurrence-events', 21: 'no-recurrence-events', 22: 'no-recurrence-events', 23: 'no-recurrence-events', 24: 'no-recurrence-events', 25: 'no-recurrence-events', 26: 'no-recurrence-events', 27: 'no-recurrence-events', 28: 'no-recurrence-events', 29: 'no-recurrence-events', 30: 'no-recurrence-events', 31: 'no-recurrence-events', 32: 'no-recurrence-events', 33: 'no-recurrence-events', 34: 'no-recurrence-events', 35: 'no-recurrenc
# ...

# %%
#remove/delete
del df1_dict["286"]
print(df1_dict)
# Out:
# {'Class': {0: 'no-recurrence-events', 1: 'no-recurrence-events', 2: 'no-recurrence-events', 3: 'no-recurrence-events', 4: 'no-recurrence-events', 5: 'no-recurrence-events', 6: 'no-recurrence-events', 7: 'no-recurrence-events', 8: 'no-recurrence-events', 9: 'no-recurrence-events', 10: 'no-recurrence-events', 11: 'no-recurrence-events', 12: 'no-recurrence-events', 13: 'no-recurrence-events', 14: 'no-recurrence-events', 15: 'no-recurrence-events', 16: 'no-recurrence-events', 17: 'no-recurrence-events', 18: 'no-recurrence-events', 19: 'no-recurrence-events', 20: 'no-recurrence-events', 21: 'no-recurrence-events', 22: 'no-recurrence-events', 23: 'no-recurrence-events', 24: 'no-recurrence-events', 25: 'no-recurrence-events', 26: 'no-recurrence-events', 27: 'no-recurrence-events', 28: 'no-recurrence-events', 29: 'no-recurrence-events', 30: 'no-recurrence-events', 31: 'no-recurrence-events', 32: 'no-recurrence-events', 33: 'no-recurrence-events', 34: 'no-recurrence-events', 35: 'no-recurrenc
# ...

# %%
#update /change
df1_dict["Cluster 5"]="hello"
print(df1_dict)
# Out:
# {'Class': {0: 'no-recurrence-events', 1: 'no-recurrence-events', 2: 'no-recurrence-events', 3: 'no-recurrence-events', 4: 'no-recurrence-events', 5: 'no-recurrence-events', 6: 'no-recurrence-events', 7: 'no-recurrence-events', 8: 'no-recurrence-events', 9: 'no-recurrence-events', 10: 'no-recurrence-events', 11: 'no-recurrence-events', 12: 'no-recurrence-events', 13: 'no-recurrence-events', 14: 'no-recurrence-events', 15: 'no-recurrence-events', 16: 'no-recurrence-events', 17: 'no-recurrence-events', 18: 'no-recurrence-events', 19: 'no-recurrence-events', 20: 'no-recurrence-events', 21: 'no-recurrence-events', 22: 'no-recurrence-events', 23: 'no-recurrence-events', 24: 'no-recurrence-events', 25: 'no-recurrence-events', 26: 'no-recurrence-events', 27: 'no-recurrence-events', 28: 'no-recurrence-events', 29: 'no-recurrence-events', 30: 'no-recurrence-events', 31: 'no-recurrence-events', 32: 'no-recurrence-events', 33: 'no-recurrence-events', 34: 'no-recurrence-events', 35: 'no-recurrenc
# ...

# %%
#join
dict1={4:"cse",6:"it",7:"ece"}
df1_dict.update(dict1)
print(df1_dict)
# Out:
# {'Class': {0: 'no-recurrence-events', 1: 'no-recurrence-events', 2: 'no-recurrence-events', 3: 'no-recurrence-events', 4: 'no-recurrence-events', 5: 'no-recurrence-events', 6: 'no-recurrence-events', 7: 'no-recurrence-events', 8: 'no-recurrence-events', 9: 'no-recurrence-events', 10: 'no-recurrence-events', 11: 'no-recurrence-events', 12: 'no-recurrence-events', 13: 'no-recurrence-events', 14: 'no-recurrence-events', 15: 'no-recurrence-events', 16: 'no-recurrence-events', 17: 'no-recurrence-events', 18: 'no-recurrence-events', 19: 'no-recurrence-events', 20: 'no-recurrence-events', 21: 'no-recurrence-events', 22: 'no-recurrence-events', 23: 'no-recurrence-events', 24: 'no-recurrence-events', 25: 'no-recurrence-events', 26: 'no-recurrence-events', 27: 'no-recurrence-events', 28: 'no-recurrence-events', 29: 'no-recurrence-events', 30: 'no-recurrence-events', 31: 'no-recurrence-events', 32: 'no-recurrence-events', 33: 'no-recurrence-events', 34: 'no-recurrence-events', 35: 'no-recurrenc
# ...

# %%
#clear all
df1_dict.clear()
print(df1_dict)
# Out:
# {}

# %%
df = data.groupby('Class')['menopause'].apply(list)

# %%
df.head
# Out:
# <bound method NDFrame.head of Class
# no-recurrence-events    [premeno, premeno, premeno, ge40, premeno, ge4...
# recurrence-events       [premeno, premeno, ge40, premeno, premeno, ge4...
# Name: menopause, dtype: object>

# %%
df_dict=df.to_dict()

# %%
#nested dict
df_dict
# Out:
# {'no-recurrence-events': ['premeno',
#   'premeno',
#   'premeno',
#   'ge40',
#   'premeno',
#   'ge40',
#   'premeno',
#   'ge40',
#   'premeno',
#   'premeno',
#   'premeno',
#   'ge40',
#   'lt40',
#   'ge40',
#   'premeno',
#   'lt40',
#   'premeno',
#   'premeno',
#   'ge40',
#   'ge40',
#   'ge40',
#   'ge40',
#   'premeno',
#   'premeno',
#   'premeno',
#   'premeno',
#   'premeno',
#   'ge40',
#   'premeno',
#   'ge40',
#   'ge40',
#   'premeno',
#   'premeno',
#   'ge40',
#   'ge40',
#   'premeno',
#   'ge40',
#   'ge40',
#   'premeno',
#   'premeno',
#   'ge40',
#   'ge40',
#   'ge40',
#   'premeno',
#   'ge40',
#   'ge40',
#   'premeno',
#   'premeno',
#   'premeno',
#   'premeno',
#   'lt40',
#   'premeno',
#   'premeno',
#   'ge40',
#   'ge40',
#   'ge40',
#   'ge40',
#   'ge40',
#   'ge40',
#   'ge40',
#   'premeno',
#   'premeno',
#   'ge40',
#   'premeno',
#   'premeno',
#   'premeno',
#   'premeno',
#   'ge40',
#   'ge40',
#   'ge40',
#   'ge40',
#   'premeno',
# ...

# %%
#change values in nested dict
df_dict["no-recurrence-events"][1]="lt40"
print(df_dict)
# Out:
# {'no-recurrence-events': ['premeno', 'lt40', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'lt40', 'ge40', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'lt40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'premeno', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'ge40', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'premeno', 'ge40', 'ge40', 'premeno', 'pre
# ...
